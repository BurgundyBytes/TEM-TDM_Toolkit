# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit
# Out:
# /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (3.1.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 12)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 15)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 15)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 15)) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 15)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->-r requirements.txt (line 15)) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 8)) (1.17.0)

# %%
# !python launcher.py
# Out:
# 2025-04-12 10:04:49,891 - src.utilities.plotting - INFO - Using matplotlib style: 'seaborn-v0_8-ticks'
# 2025-04-12 10:04:55,149 - __main__ - INFO - Using default configuration file: config.txt
# 2025-04-12 10:04:55,149 - __main__ - INFO - --- Signal Processing Plant Startup ---
# 2025-04-12 10:04:55,997 - src.controllers.configuration - INFO - Configuration loaded successfully from 'config.txt'.
# 2025-04-12 10:04:55,997 - __main__ - INFO - Workflow control flags:
# 2025-04-12 10:04:55,997 - __main__ - INFO - 	execute: True
# 2025-04-12 10:04:55,997 - __main__ - INFO - 	results: True
# 2025-04-12 10:04:55,997 - __main__ - INFO - 	optima: True
# 2025-04-12 10:04:55,997 - __main__ - INFO - 	nyquist: True
# 2025-04-12 10:04:55,997 - __main__ - INFO - 	fourier: True
# 2025-04-12 10:04:55,997 - __main__ - INFO - 	plots: True
# 2025-04-12 10:04:55,997 - __main__ - INFO - 	logs: True
# 2025-04-12 10:04:55,997 - __main__ - INFO - 	pickle: True
# 2025-04-12 10:04:55,998 - src.controllers.configuration - INFO - Base output path for this run: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin
# 2025-04-12 10:04:56,005 - src.controllers.configuration - INFO - Execution Flow active. Checking parametric study flags.
# 2025-04-12 10:04:56,005 - src.controllers.configuration - INFO - 	Skipping Parametric Freq folder (Run Parametric Freq is False).
# 2025-04-12 10:04:56,005 - src.controllers.configuration - INFO - 	Creating/Verifying Parametric Delta folder: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/parametric_delta
# 2025-04-12 10:04:56,008 - src.controllers.configuration - INFO - 	Skipping Biparametric folder (Run Biparametric is False).
# 2025-04-12 10:04:56,008 - src.controllers.configuration - INFO - Results Flow active. Checking analysis flags.
# 2025-04-12 10:04:56,008 - src.controllers.configuration - INFO - 	Creating/Verifying Nyquist folder: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/nyquist
# 2025-04-12 10:04:56,011 - src.controllers.configuration - INFO - 	Creating/Verifying Optima folder: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/optima
# 2025-04-12 10:04:56,013 - src.controllers.configuration - INFO - 	Creating/Verifying Fourier folder: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/fourier
# 2025-04-12 10:04:56,017 - __main__ - INFO - Output folder paths configured:
# 2025-04-12 10:04:56,017 - __main__ - INFO - 	base_subcase: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin
# 2025-04-12 10:04:56,017 - __main__ - INFO - 	param_freq: (Not Created/Needed)
# 2025-04-12 10:04:56,017 - __main__ - INFO - 	param_delta: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/parametric_delta
# 2025-04-12 10:04:56,017 - __main__ - INFO - 	biparametric: (Not Created/Needed)
# 2025-04-12 10:04:56,017 - __main__ - INFO - 	nyquist: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/nyquist
# 2025-04-12 10:04:56,017 - __main__ - INFO - 	optima: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/optima
# 2025-04-12 10:04:56,017 - __main__ - INFO - 	fourier: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/fourier
# 2025-04-12 10:04:56,017 - __main__ - INFO - --- Input Handler ---
# 2025-04-12 10:04:56,017 - src.controllers.input_handler - INFO - Input Source: generated
# 2025-04-12 10:04:56,017 - src.controllers.input_handler - INFO - Generating signal type: multisin (Fs=20000.0 Hz, Dur=1.0 s)
# 2025-04-12 10:04:56,023 - src.controllers.input_handler - INFO - Input handler finished: Produced 1 signal(s).
# 2025-04-12 10:04:56,023 - __main__ - INFO - Input signals generated/loaded: ['generated_multisin']
# 2025-04-12 10:04:56,023 - __main__ - INFO -
# --- Starting Execution Workflow (Parametric Handler) ---
# 2025-04-12 10:04:56,023 - src.controllers.parametric_handler - INFO - === Parametric Handler Manager ===
# 2025-04-12 10:04:56,023 - src.controllers.parametric_handler - INFO -
# Processing signal: generated_multisin...
# 2025-04-12 10:04:56,026 - src.controllers.parametric_handler - INFO -   Using stable region indices [1000:19000] for metrics.
# 2025-04-12 10:04:56,026 - src.controllers.parametric_handler - INFO - 	Running Delta study for generated_multisin...
# 2025-04-12 10:04:56,026 - src.controllers.parametric_handler - INFO - 		Params: Delta Range=(0.0001, 0.1, 0.0001), Default Fs=20000.0 Hz
# 2025-04-12 10:04:56,026 - src.controllers.parametric_handler - INFO - 		Saving outputs to: /content/drive/MyDrive/Colab Notebooks/TEM-TDM Toolkit/Output/generated/multisin/parametric_delta
# 2025-04-12 10:04:56,039 - src.parametric.studies - INFO - Initialized study log file: parametric_delta-generated_multisin.txt
# 2025-04-12 10:04:56,039 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0001): b=1.000, dte=0.0e+00...
# 2025-04-12 10:05:59,371 - src.parametric.studies - INFO - 	(fs=20000_d=0.0001) Done. MaxErr=9.19e-02, MedErr=-2.99e-04, NSpikes=3694, Time=63.31s
# 2025-04-12 10:06:01,938 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0002): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:13,234 - src.parametric.studies - INFO - 	(fs=20000_d=0.0002) Done. MaxErr=8.83e-02, MedErr=-5.72e-03, NSpikes=1943, Time=11.29s
# 2025-04-12 10:06:15,058 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0003): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:18,186 - src.parametric.studies - INFO - 	(fs=20000_d=0.0003) Done. MaxErr=7.93e-02, MedErr=2.93e-03, NSpikes=1318, Time=3.12s
# 2025-04-12 10:06:20,801 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0004): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:22,718 - src.parametric.studies - INFO - 	(fs=20000_d=0.0004) Done. MaxErr=7.36e-02, MedErr=-1.14e-03, NSpikes=995, Time=1.91s
# 2025-04-12 10:06:24,630 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0005): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:25,620 - src.parametric.studies - INFO - 	(fs=20000_d=0.0005) Done. MaxErr=8.73e-02, MedErr=-1.88e-03, NSpikes=802, Time=0.99s
# 2025-04-12 10:06:27,306 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0006): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:28,050 - src.parametric.studies - INFO - 	(fs=20000_d=0.0006) Done. MaxErr=6.17e-02, MedErr=7.63e-04, NSpikes=670, Time=0.74s
# 2025-04-12 10:06:29,748 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0007): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:30,356 - src.parametric.studies - INFO - 	(fs=20000_d=0.0007) Done. MaxErr=6.18e-02, MedErr=3.29e-03, NSpikes=576, Time=0.61s
# 2025-04-12 10:06:32,430 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0008): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:33,531 - src.parametric.studies - INFO - 	(fs=20000_d=0.0008) Done. MaxErr=4.39e-02, MedErr=-3.89e-03, NSpikes=505, Time=1.10s
# 2025-04-12 10:06:36,155 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0009): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:36,570 - src.parametric.studies - INFO - 	(fs=20000_d=0.0009) Done. MaxErr=4.24e-02, MedErr=2.15e-03, NSpikes=449, Time=0.41s
# 2025-04-12 10:06:38,269 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0010): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:38,642 - src.parametric.studies - INFO - 	(fs=20000_d=0.0010) Done. MaxErr=4.27e-02, MedErr=1.82e-04, NSpikes=405, Time=0.37s
# 2025-04-12 10:06:40,341 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0011): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:40,667 - src.parametric.studies - INFO - 	(fs=20000_d=0.0011) Done. MaxErr=4.68e-02, MedErr=-4.57e-03, NSpikes=368, Time=0.32s
# 2025-04-12 10:06:42,378 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0012): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:42,670 - src.parametric.studies - INFO - 	(fs=20000_d=0.0012) Done. MaxErr=1.75e-02, MedErr=-1.95e-03, NSpikes=338, Time=0.29s
# 2025-04-12 10:06:44,576 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0013): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:44,856 - src.parametric.studies - INFO - 	(fs=20000_d=0.0013) Done. MaxErr=3.35e-02, MedErr=4.86e-04, NSpikes=312, Time=0.28s
# 2025-04-12 10:06:47,120 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0014): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:47,532 - src.parametric.studies - INFO - 	(fs=20000_d=0.0014) Done. MaxErr=2.52e-02, MedErr=-1.79e-03, NSpikes=290, Time=0.41s
# 2025-04-12 10:06:49,882 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0015): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:50,130 - src.parametric.studies - INFO - 	(fs=20000_d=0.0015) Done. MaxErr=1.82e-02, MedErr=2.57e-04, NSpikes=271, Time=0.24s
# 2025-04-12 10:06:51,994 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0016): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:52,220 - src.parametric.studies - INFO - 	(fs=20000_d=0.0016) Done. MaxErr=1.93e-02, MedErr=-4.81e-04, NSpikes=254, Time=0.22s
# 2025-04-12 10:06:53,907 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0017): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:54,127 - src.parametric.studies - INFO - 	(fs=20000_d=0.0017) Done. MaxErr=1.19e-02, MedErr=-2.79e-04, NSpikes=239, Time=0.22s
# 2025-04-12 10:06:55,812 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0018): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:56,027 - src.parametric.studies - INFO - 	(fs=20000_d=0.0018) Done. MaxErr=8.23e-03, MedErr=-7.99e-05, NSpikes=226, Time=0.21s
# 2025-04-12 10:06:57,724 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0019): b=1.000, dte=0.0e+00...
# 2025-04-12 10:06:57,939 - src.parametric.studies - INFO - 	(fs=20000_d=0.0019) Done. MaxErr=6.88e-03, MedErr=3.33e-04, NSpikes=214, Time=0.21s
# 2025-04-12 10:06:59,932 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0020): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:00,213 - src.parametric.studies - INFO - 	(fs=20000_d=0.0020) Done. MaxErr=9.95e-03, MedErr=-3.63e-05, NSpikes=203, Time=0.28s
# 2025-04-12 10:07:02,803 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0021): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:03,070 - src.parametric.studies - INFO - 	(fs=20000_d=0.0021) Done. MaxErr=7.45e-03, MedErr=2.21e-05, NSpikes=193, Time=0.26s
# 2025-04-12 10:07:04,940 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0022): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:05,124 - src.parametric.studies - INFO - 	(fs=20000_d=0.0022) Done. MaxErr=7.01e-03, MedErr=3.24e-05, NSpikes=185, Time=0.18s
# 2025-04-12 10:07:06,971 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0023): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:07,148 - src.parametric.studies - INFO - 	(fs=20000_d=0.0023) Done. MaxErr=4.82e-03, MedErr=-3.78e-04, NSpikes=176, Time=0.17s
# 2025-04-12 10:07:09,081 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0024): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:09,252 - src.parametric.studies - INFO - 	(fs=20000_d=0.0024) Done. MaxErr=1.13e-02, MedErr=4.09e-05, NSpikes=169, Time=0.17s
# 2025-04-12 10:07:10,956 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0025): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:11,121 - src.parametric.studies - INFO - 	(fs=20000_d=0.0025) Done. MaxErr=6.78e-03, MedErr=2.17e-04, NSpikes=162, Time=0.16s
# 2025-04-12 10:07:12,839 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0026): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:13,009 - src.parametric.studies - INFO - 	(fs=20000_d=0.0026) Done. MaxErr=5.76e-03, MedErr=-3.98e-04, NSpikes=156, Time=0.17s
# 2025-04-12 10:07:15,284 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0027): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:15,857 - src.parametric.studies - INFO - 	(fs=20000_d=0.0027) Done. MaxErr=7.22e-03, MedErr=-2.47e-04, NSpikes=150, Time=0.57s
# 2025-04-12 10:07:18,240 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0028): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:18,405 - src.parametric.studies - INFO - 	(fs=20000_d=0.0028) Done. MaxErr=4.87e-03, MedErr=-2.03e-04, NSpikes=145, Time=0.16s
# 2025-04-12 10:07:20,079 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0029): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:20,227 - src.parametric.studies - INFO - 	(fs=20000_d=0.0029) Done. MaxErr=6.34e-03, MedErr=2.54e-04, NSpikes=140, Time=0.14s
# 2025-04-12 10:07:21,869 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0030): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:22,051 - src.parametric.studies - INFO - 	(fs=20000_d=0.0030) Done. MaxErr=5.81e-03, MedErr=8.83e-05, NSpikes=135, Time=0.18s
# 2025-04-12 10:07:23,707 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0031): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:23,847 - src.parametric.studies - INFO - 	(fs=20000_d=0.0031) Done. MaxErr=5.69e-03, MedErr=1.13e-04, NSpikes=131, Time=0.14s
# 2025-04-12 10:07:25,706 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0032): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:25,840 - src.parametric.studies - INFO - 	(fs=20000_d=0.0032) Done. MaxErr=7.30e-03, MedErr=4.88e-04, NSpikes=127, Time=0.13s
# 2025-04-12 10:07:27,461 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0033): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:27,640 - src.parametric.studies - INFO - 	(fs=20000_d=0.0033) Done. MaxErr=1.44e-02, MedErr=2.77e-04, NSpikes=123, Time=0.18s
# 2025-04-12 10:07:30,176 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0034): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:30,731 - src.parametric.studies - INFO - 	(fs=20000_d=0.0034) Done. MaxErr=5.22e-03, MedErr=2.87e-05, NSpikes=119, Time=0.55s
# 2025-04-12 10:07:32,573 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0035): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:32,697 - src.parametric.studies - INFO - 	(fs=20000_d=0.0035) Done. MaxErr=6.25e-03, MedErr=9.43e-05, NSpikes=116, Time=0.12s
# 2025-04-12 10:07:34,603 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0036): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:34,726 - src.parametric.studies - INFO - 	(fs=20000_d=0.0036) Done. MaxErr=1.41e-02, MedErr=7.85e-04, NSpikes=113, Time=0.12s
# 2025-04-12 10:07:36,334 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0037): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:36,458 - src.parametric.studies - INFO - 	(fs=20000_d=0.0037) Done. MaxErr=5.46e-03, MedErr=1.31e-04, NSpikes=110, Time=0.12s
# 2025-04-12 10:07:38,078 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0038): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:38,197 - src.parametric.studies - INFO - 	(fs=20000_d=0.0038) Done. MaxErr=7.33e-03, MedErr=1.38e-04, NSpikes=107, Time=0.12s
# 2025-04-12 10:07:39,799 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0039): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:39,914 - src.parametric.studies - INFO - 	(fs=20000_d=0.0039) Done. MaxErr=5.92e-03, MedErr=2.08e-04, NSpikes=104, Time=0.11s
# 2025-04-12 10:07:41,937 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0040): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:42,441 - src.parametric.studies - INFO - 	(fs=20000_d=0.0040) Done. MaxErr=1.48e-02, MedErr=-6.15e-04, NSpikes=101, Time=0.50s
# 2025-04-12 10:07:44,996 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0041): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:45,184 - src.parametric.studies - INFO - 	(fs=20000_d=0.0041) Done. MaxErr=7.23e-03, MedErr=3.19e-04, NSpikes=99, Time=0.19s
# 2025-04-12 10:07:46,970 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0042): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:47,079 - src.parametric.studies - INFO - 	(fs=20000_d=0.0042) Done. MaxErr=2.08e-02, MedErr=-1.44e-03, NSpikes=96, Time=0.11s
# 2025-04-12 10:07:48,707 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0043): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:48,815 - src.parametric.studies - INFO - 	(fs=20000_d=0.0043) Done. MaxErr=2.75e-02, MedErr=-1.04e-03, NSpikes=94, Time=0.10s
# 2025-04-12 10:07:50,611 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0044): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:50,719 - src.parametric.studies - INFO - 	(fs=20000_d=0.0044) Done. MaxErr=1.08e-02, MedErr=8.70e-05, NSpikes=91, Time=0.10s
# 2025-04-12 10:07:52,353 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0045): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:52,458 - src.parametric.studies - INFO - 	(fs=20000_d=0.0045) Done. MaxErr=1.05e-02, MedErr=5.02e-05, NSpikes=90, Time=0.10s
# 2025-04-12 10:07:54,073 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0046): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:54,188 - src.parametric.studies - INFO - 	(fs=20000_d=0.0046) Done. MaxErr=1.01e-02, MedErr=9.64e-06, NSpikes=88, Time=0.11s
# 2025-04-12 10:07:56,057 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0047): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:56,537 - src.parametric.studies - INFO - 	(fs=20000_d=0.0047) Done. MaxErr=6.44e-03, MedErr=-5.55e-04, NSpikes=86, Time=0.48s
# 2025-04-12 10:07:59,268 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0048): b=1.000, dte=0.0e+00...
# 2025-04-12 10:07:59,496 - src.parametric.studies - INFO - 	(fs=20000_d=0.0048) Done. MaxErr=1.53e-02, MedErr=3.03e-04, NSpikes=84, Time=0.22s
# 2025-04-12 10:08:01,104 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0049): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:01,206 - src.parametric.studies - INFO - 	(fs=20000_d=0.0049) Done. MaxErr=1.70e-02, MedErr=-2.05e-04, NSpikes=82, Time=0.10s
# 2025-04-12 10:08:02,833 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0050): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:02,931 - src.parametric.studies - INFO - 	(fs=20000_d=0.0050) Done. MaxErr=1.10e-02, MedErr=-6.56e-04, NSpikes=80, Time=0.09s
# 2025-04-12 10:08:04,603 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0051): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:04,698 - src.parametric.studies - INFO - 	(fs=20000_d=0.0051) Done. MaxErr=2.08e-02, MedErr=-4.33e-05, NSpikes=79, Time=0.09s
# 2025-04-12 10:08:06,527 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0052): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:06,620 - src.parametric.studies - INFO - 	(fs=20000_d=0.0052) Done. MaxErr=1.30e-02, MedErr=-2.96e-04, NSpikes=77, Time=0.09s
# 2025-04-12 10:08:08,260 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0053): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:08,366 - src.parametric.studies - INFO - 	(fs=20000_d=0.0053) Done. MaxErr=5.23e-02, MedErr=4.90e-04, NSpikes=76, Time=0.10s
# 2025-04-12 10:08:10,319 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0054): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:10,447 - src.parametric.studies - INFO - 	(fs=20000_d=0.0054) Done. MaxErr=1.97e-02, MedErr=4.09e-05, NSpikes=74, Time=0.12s
# 2025-04-12 10:08:12,961 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0055): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:13,102 - src.parametric.studies - INFO - 	(fs=20000_d=0.0055) Done. MaxErr=3.03e-02, MedErr=1.83e-03, NSpikes=73, Time=0.14s
# 2025-04-12 10:08:14,824 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0056): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:14,914 - src.parametric.studies - INFO - 	(fs=20000_d=0.0056) Done. MaxErr=5.64e-02, MedErr=-5.87e-05, NSpikes=71, Time=0.09s
# 2025-04-12 10:08:16,758 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0057): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:16,846 - src.parametric.studies - INFO - 	(fs=20000_d=0.0057) Done. MaxErr=5.96e-02, MedErr=1.54e-04, NSpikes=70, Time=0.09s
# 2025-04-12 10:08:18,469 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0058): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:18,555 - src.parametric.studies - INFO - 	(fs=20000_d=0.0058) Done. MaxErr=1.75e-01, MedErr=-1.97e-04, NSpikes=68, Time=0.08s
# 2025-04-12 10:08:20,174 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0059): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:20,266 - src.parametric.studies - INFO - 	(fs=20000_d=0.0059) Done. MaxErr=5.09e-01, MedErr=4.23e-04, NSpikes=68, Time=0.09s
# 2025-04-12 10:08:21,872 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0060): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:21,959 - src.parametric.studies - INFO - 	(fs=20000_d=0.0060) Done. MaxErr=7.12e-02, MedErr=2.32e-04, NSpikes=67, Time=0.08s
# 2025-04-12 10:08:24,005 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0061): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:24,126 - src.parametric.studies - INFO - 	(fs=20000_d=0.0061) Done. MaxErr=1.44e-01, MedErr=9.83e-05, NSpikes=66, Time=0.12s
# 2025-04-12 10:08:26,592 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0062): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:26,725 - src.parametric.studies - INFO - 	(fs=20000_d=0.0062) Done. MaxErr=1.36e-01, MedErr=-1.30e-04, NSpikes=64, Time=0.13s
# 2025-04-12 10:08:28,554 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0063): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:28,637 - src.parametric.studies - INFO - 	(fs=20000_d=0.0063) Done. MaxErr=2.62e-01, MedErr=1.12e-04, NSpikes=63, Time=0.08s
# 2025-04-12 10:08:30,255 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0064): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:30,580 - src.parametric.studies - INFO - 	(fs=20000_d=0.0064) Done. MaxErr=4.07e-01, MedErr=1.69e-04, NSpikes=63, Time=0.31s
# 2025-04-12 10:08:33,241 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0065): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:33,366 - src.parametric.studies - INFO - 	(fs=20000_d=0.0065) Done. MaxErr=4.69e-01, MedErr=-1.50e-04, NSpikes=61, Time=0.12s
# 2025-04-12 10:08:35,388 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0066): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:35,476 - src.parametric.studies - INFO - 	(fs=20000_d=0.0066) Done. MaxErr=3.50e-01, MedErr=3.40e-04, NSpikes=60, Time=0.08s
# 2025-04-12 10:08:37,458 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0067): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:37,639 - src.parametric.studies - INFO - 	(fs=20000_d=0.0067) Done. MaxErr=1.20e-01, MedErr=3.07e-04, NSpikes=59, Time=0.17s
# 2025-04-12 10:08:41,686 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0068): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:41,925 - src.parametric.studies - INFO - 	(fs=20000_d=0.0068) Done. MaxErr=2.71e-02, MedErr=2.15e-05, NSpikes=58, Time=0.23s
# 2025-04-12 10:08:44,294 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0069): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:44,376 - src.parametric.studies - INFO - 	(fs=20000_d=0.0069) Done. MaxErr=2.11e-02, MedErr=4.17e-05, NSpikes=57, Time=0.08s
# 2025-04-12 10:08:46,057 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0070): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:46,134 - src.parametric.studies - INFO - 	(fs=20000_d=0.0070) Done. MaxErr=6.59e-03, MedErr=3.25e-04, NSpikes=56, Time=0.07s
# 2025-04-12 10:08:47,825 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0071): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:47,904 - src.parametric.studies - INFO - 	(fs=20000_d=0.0071) Done. MaxErr=6.31e-03, MedErr=-2.45e-05, NSpikes=55, Time=0.08s
# 2025-04-12 10:08:49,593 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0072): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:49,684 - src.parametric.studies - INFO - 	(fs=20000_d=0.0072) Done. MaxErr=1.05e-02, MedErr=-3.13e-05, NSpikes=54, Time=0.09s
# 2025-04-12 10:08:51,507 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0073): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:51,584 - src.parametric.studies - INFO - 	(fs=20000_d=0.0073) Done. MaxErr=1.20e-02, MedErr=-1.49e-04, NSpikes=54, Time=0.07s
# 2025-04-12 10:08:53,259 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0074): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:53,347 - src.parametric.studies - INFO - 	(fs=20000_d=0.0074) Done. MaxErr=1.46e-02, MedErr=-2.34e-04, NSpikes=54, Time=0.08s
# 2025-04-12 10:08:55,954 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0075): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:56,092 - src.parametric.studies - INFO - 	(fs=20000_d=0.0075) Done. MaxErr=2.55e-02, MedErr=-2.54e-04, NSpikes=54, Time=0.13s
# 2025-04-12 10:08:58,154 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0076): b=1.000, dte=0.0e+00...
# 2025-04-12 10:08:58,228 - src.parametric.studies - INFO - 	(fs=20000_d=0.0076) Done. MaxErr=4.33e-02, MedErr=-7.76e-05, NSpikes=52, Time=0.07s
# 2025-04-12 10:09:00,085 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0077): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:00,159 - src.parametric.studies - INFO - 	(fs=20000_d=0.0077) Done. MaxErr=5.45e-02, MedErr=5.46e-05, NSpikes=51, Time=0.07s
# 2025-04-12 10:09:01,778 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0078): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:01,858 - src.parametric.studies - INFO - 	(fs=20000_d=0.0078) Done. MaxErr=3.33e-01, MedErr=-1.95e-03, NSpikes=50, Time=0.08s
# 2025-04-12 10:09:03,474 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0079): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:03,549 - src.parametric.studies - INFO - 	(fs=20000_d=0.0079) Done. MaxErr=3.52e-01, MedErr=8.08e-04, NSpikes=49, Time=0.07s
# 2025-04-12 10:09:05,173 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0080): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:05,261 - src.parametric.studies - INFO - 	(fs=20000_d=0.0080) Done. MaxErr=3.25e-01, MedErr=-2.06e-03, NSpikes=48, Time=0.09s
# 2025-04-12 10:09:06,931 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0081): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:07,004 - src.parametric.studies - INFO - 	(fs=20000_d=0.0081) Done. MaxErr=3.63e-01, MedErr=2.27e-04, NSpikes=47, Time=0.07s
# 2025-04-12 10:09:09,778 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0082): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:09,900 - src.parametric.studies - INFO - 	(fs=20000_d=0.0082) Done. MaxErr=3.34e-01, MedErr=2.94e-03, NSpikes=47, Time=0.11s
# 2025-04-12 10:09:12,008 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0083): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:12,081 - src.parametric.studies - INFO - 	(fs=20000_d=0.0083) Done. MaxErr=3.16e-01, MedErr=-4.24e-03, NSpikes=46, Time=0.07s
# 2025-04-12 10:09:13,706 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0084): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:13,777 - src.parametric.studies - INFO - 	(fs=20000_d=0.0084) Done. MaxErr=3.62e-01, MedErr=1.60e-03, NSpikes=45, Time=0.07s
# 2025-04-12 10:09:15,407 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0085): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:15,476 - src.parametric.studies - INFO - 	(fs=20000_d=0.0085) Done. MaxErr=2.11e-01, MedErr=-1.83e-04, NSpikes=44, Time=0.07s
# 2025-04-12 10:09:17,429 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0086): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:17,498 - src.parametric.studies - INFO - 	(fs=20000_d=0.0086) Done. MaxErr=2.41e-01, MedErr=2.97e-04, NSpikes=43, Time=0.07s
# 2025-04-12 10:09:19,133 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0087): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:19,205 - src.parametric.studies - INFO - 	(fs=20000_d=0.0087) Done. MaxErr=2.65e-01, MedErr=-1.31e-03, NSpikes=42, Time=0.07s
# 2025-04-12 10:09:20,839 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0088): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:20,894 - src.parametric.studies - INFO - 	(fs=20000_d=0.0088) Done. MaxErr=3.03e-01, MedErr=-1.41e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:23,157 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0089): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:23,252 - src.parametric.studies - INFO - 	(fs=20000_d=0.0089) Done. MaxErr=3.19e-01, MedErr=-1.58e-03, NSpikes=40, Time=0.09s
# 2025-04-12 10:09:25,736 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0090): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:25,793 - src.parametric.studies - INFO - 	(fs=20000_d=0.0090) Done. MaxErr=3.33e-01, MedErr=-1.43e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:27,366 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0091): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:27,420 - src.parametric.studies - INFO - 	(fs=20000_d=0.0091) Done. MaxErr=3.45e-01, MedErr=-1.48e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:29,007 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0092): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:29,063 - src.parametric.studies - INFO - 	(fs=20000_d=0.0092) Done. MaxErr=3.60e-01, MedErr=-1.84e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:30,646 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0093): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:30,701 - src.parametric.studies - INFO - 	(fs=20000_d=0.0093) Done. MaxErr=3.74e-01, MedErr=-1.66e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:32,487 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0094): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:32,544 - src.parametric.studies - INFO - 	(fs=20000_d=0.0094) Done. MaxErr=3.87e-01, MedErr=-1.83e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:34,144 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0095): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:34,203 - src.parametric.studies - INFO - 	(fs=20000_d=0.0095) Done. MaxErr=4.01e-01, MedErr=-1.84e-03, NSpikes=40, Time=0.06s
# 2025-04-12 10:09:36,186 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0096): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:36,284 - src.parametric.studies - INFO - 	(fs=20000_d=0.0096) Done. MaxErr=4.12e-01, MedErr=-1.70e-03, NSpikes=40, Time=0.09s
# 2025-04-12 10:09:38,721 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0097): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:38,818 - src.parametric.studies - INFO - 	(fs=20000_d=0.0097) Done. MaxErr=4.20e-01, MedErr=-1.91e-03, NSpikes=40, Time=0.09s
# 2025-04-12 10:09:40,494 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0098): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:40,550 - src.parametric.studies - INFO - 	(fs=20000_d=0.0098) Done. MaxErr=4.31e-01, MedErr=-1.82e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:42,376 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0099): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:42,431 - src.parametric.studies - INFO - 	(fs=20000_d=0.0099) Done. MaxErr=4.37e-01, MedErr=-2.16e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:44,018 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0100): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:44,073 - src.parametric.studies - INFO - 	(fs=20000_d=0.0100) Done. MaxErr=4.45e-01, MedErr=-2.38e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:45,664 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0101): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:45,721 - src.parametric.studies - INFO - 	(fs=20000_d=0.0101) Done. MaxErr=4.52e-01, MedErr=-2.16e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:47,319 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0102): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:47,373 - src.parametric.studies - INFO - 	(fs=20000_d=0.0102) Done. MaxErr=4.58e-01, MedErr=-2.28e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:49,150 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0103): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:49,249 - src.parametric.studies - INFO - 	(fs=20000_d=0.0103) Done. MaxErr=4.63e-01, MedErr=-2.65e-03, NSpikes=40, Time=0.10s
# 2025-04-12 10:09:51,747 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0104): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:51,863 - src.parametric.studies - INFO - 	(fs=20000_d=0.0104) Done. MaxErr=4.67e-01, MedErr=-2.81e-03, NSpikes=40, Time=0.11s
# 2025-04-12 10:09:53,877 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0105): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:53,934 - src.parametric.studies - INFO - 	(fs=20000_d=0.0105) Done. MaxErr=4.70e-01, MedErr=-2.26e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:55,519 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0106): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:55,573 - src.parametric.studies - INFO - 	(fs=20000_d=0.0106) Done. MaxErr=4.79e-01, MedErr=-2.62e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:57,405 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0107): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:57,460 - src.parametric.studies - INFO - 	(fs=20000_d=0.0107) Done. MaxErr=4.84e-01, MedErr=-2.89e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:09:59,046 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0108): b=1.000, dte=0.0e+00...
# 2025-04-12 10:09:59,101 - src.parametric.studies - INFO - 	(fs=20000_d=0.0108) Done. MaxErr=4.93e-01, MedErr=-2.34e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:00,744 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0109): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:00,799 - src.parametric.studies - INFO - 	(fs=20000_d=0.0109) Done. MaxErr=4.97e-01, MedErr=-2.10e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:02,369 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0110): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:02,424 - src.parametric.studies - INFO - 	(fs=20000_d=0.0110) Done. MaxErr=5.04e-01, MedErr=-2.45e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:04,762 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0111): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:04,859 - src.parametric.studies - INFO - 	(fs=20000_d=0.0111) Done. MaxErr=5.11e-01, MedErr=-2.27e-03, NSpikes=40, Time=0.09s
# 2025-04-12 10:10:07,258 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0112): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:07,319 - src.parametric.studies - INFO - 	(fs=20000_d=0.0112) Done. MaxErr=5.16e-01, MedErr=-1.93e-03, NSpikes=40, Time=0.06s
# 2025-04-12 10:10:08,890 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0113): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:08,952 - src.parametric.studies - INFO - 	(fs=20000_d=0.0113) Done. MaxErr=5.20e-01, MedErr=-1.75e-03, NSpikes=40, Time=0.06s
# 2025-04-12 10:10:10,517 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0114): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:10,574 - src.parametric.studies - INFO - 	(fs=20000_d=0.0114) Done. MaxErr=5.24e-01, MedErr=-1.44e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:12,169 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0115): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:12,226 - src.parametric.studies - INFO - 	(fs=20000_d=0.0115) Done. MaxErr=5.29e-01, MedErr=-1.33e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:14,024 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0116): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:14,079 - src.parametric.studies - INFO - 	(fs=20000_d=0.0116) Done. MaxErr=5.31e-01, MedErr=-9.98e-04, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:15,689 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0117): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:15,744 - src.parametric.studies - INFO - 	(fs=20000_d=0.0117) Done. MaxErr=5.33e-01, MedErr=-1.09e-03, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:17,526 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0118): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:17,626 - src.parametric.studies - INFO - 	(fs=20000_d=0.0118) Done. MaxErr=5.37e-01, MedErr=-8.38e-04, NSpikes=40, Time=0.10s
# 2025-04-12 10:10:20,026 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0119): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:20,126 - src.parametric.studies - INFO - 	(fs=20000_d=0.0119) Done. MaxErr=5.39e-01, MedErr=-1.92e-04, NSpikes=40, Time=0.10s
# 2025-04-12 10:10:22,162 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0120): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:22,218 - src.parametric.studies - INFO - 	(fs=20000_d=0.0120) Done. MaxErr=5.37e-01, MedErr=-1.02e-04, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:23,826 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0121): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:23,881 - src.parametric.studies - INFO - 	(fs=20000_d=0.0121) Done. MaxErr=5.36e-01, MedErr=1.00e-04, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:25,517 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0122): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:25,573 - src.parametric.studies - INFO - 	(fs=20000_d=0.0122) Done. MaxErr=5.32e-01, MedErr=3.86e-04, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:27,167 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0123): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:27,222 - src.parametric.studies - INFO - 	(fs=20000_d=0.0123) Done. MaxErr=5.21e-01, MedErr=5.25e-04, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:29,038 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0124): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:29,095 - src.parametric.studies - INFO - 	(fs=20000_d=0.0124) Done. MaxErr=5.12e-01, MedErr=4.86e-04, NSpikes=40, Time=0.05s
# 2025-04-12 10:10:30,749 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0125): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:30,802 - src.parametric.studies - INFO - 	(fs=20000_d=0.0125) Done. MaxErr=5.39e-01, MedErr=7.01e-04, NSpikes=37, Time=0.05s
# 2025-04-12 10:10:33,300 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0126): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:33,400 - src.parametric.studies - INFO - 	(fs=20000_d=0.0126) Done. MaxErr=7.06e-01, MedErr=3.28e-03, NSpikes=37, Time=0.10s
# 2025-04-12 10:10:35,520 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0127): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:35,576 - src.parametric.studies - INFO - 	(fs=20000_d=0.0127) Done. MaxErr=6.64e-01, MedErr=-1.21e-02, NSpikes=37, Time=0.05s
# 2025-04-12 10:10:37,220 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0128): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:37,279 - src.parametric.studies - INFO - 	(fs=20000_d=0.0128) Done. MaxErr=5.01e-01, MedErr=-1.18e-02, NSpikes=37, Time=0.06s
# 2025-04-12 10:10:39,084 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0129): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:39,136 - src.parametric.studies - INFO - 	(fs=20000_d=0.0129) Done. MaxErr=6.31e-01, MedErr=-1.13e-02, NSpikes=35, Time=0.05s
# 2025-04-12 10:10:40,723 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0130): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:40,778 - src.parametric.studies - INFO - 	(fs=20000_d=0.0130) Done. MaxErr=6.45e-01, MedErr=6.28e-03, NSpikes=35, Time=0.05s
# 2025-04-12 10:10:42,408 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0131): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:42,459 - src.parametric.studies - INFO - 	(fs=20000_d=0.0131) Done. MaxErr=6.81e-01, MedErr=-4.76e-03, NSpikes=33, Time=0.05s
# 2025-04-12 10:10:44,043 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0132): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:44,109 - src.parametric.studies - INFO - 	(fs=20000_d=0.0132) Done. MaxErr=6.76e-01, MedErr=1.19e-03, NSpikes=33, Time=0.06s
# 2025-04-12 10:10:46,459 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0133): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:46,548 - src.parametric.studies - INFO - 	(fs=20000_d=0.0133) Done. MaxErr=6.40e-01, MedErr=-3.65e-03, NSpikes=33, Time=0.09s
# 2025-04-12 10:10:48,962 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0134): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:49,015 - src.parametric.studies - INFO - 	(fs=20000_d=0.0134) Done. MaxErr=5.87e-01, MedErr=-8.08e-03, NSpikes=33, Time=0.05s
# 2025-04-12 10:10:50,653 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0135): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:50,706 - src.parametric.studies - INFO - 	(fs=20000_d=0.0135) Done. MaxErr=5.26e-01, MedErr=-5.93e-03, NSpikes=33, Time=0.05s
# 2025-04-12 10:10:52,319 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0136): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:52,370 - src.parametric.studies - INFO - 	(fs=20000_d=0.0136) Done. MaxErr=4.66e-01, MedErr=2.25e-03, NSpikes=33, Time=0.05s
# 2025-04-12 10:10:54,232 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0137): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:54,298 - src.parametric.studies - INFO - 	(fs=20000_d=0.0137) Done. MaxErr=4.14e-01, MedErr=1.01e-02, NSpikes=32, Time=0.06s
# 2025-04-12 10:10:55,913 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0138): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:55,966 - src.parametric.studies - INFO - 	(fs=20000_d=0.0138) Done. MaxErr=6.81e-01, MedErr=1.30e-02, NSpikes=32, Time=0.05s
# 2025-04-12 10:10:57,581 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0139): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:57,634 - src.parametric.studies - INFO - 	(fs=20000_d=0.0139) Done. MaxErr=8.21e-01, MedErr=-8.61e-03, NSpikes=31, Time=0.05s
# 2025-04-12 10:10:59,536 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0140): b=1.000, dte=0.0e+00...
# 2025-04-12 10:10:59,626 - src.parametric.studies - INFO - 	(fs=20000_d=0.0140) Done. MaxErr=7.52e-01, MedErr=6.14e-03, NSpikes=31, Time=0.09s
# 2025-04-12 10:11:02,333 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0141): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:02,423 - src.parametric.studies - INFO - 	(fs=20000_d=0.0141) Done. MaxErr=9.39e-01, MedErr=-5.05e-04, NSpikes=30, Time=0.09s
# 2025-04-12 10:11:04,172 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0142): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:04,221 - src.parametric.studies - INFO - 	(fs=20000_d=0.0142) Done. MaxErr=8.14e-01, MedErr=6.49e-03, NSpikes=30, Time=0.05s
# 2025-04-12 10:11:05,851 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0143): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:05,902 - src.parametric.studies - INFO - 	(fs=20000_d=0.0143) Done. MaxErr=7.85e-01, MedErr=-1.54e-02, NSpikes=30, Time=0.05s
# 2025-04-12 10:11:07,512 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0144): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:07,561 - src.parametric.studies - INFO - 	(fs=20000_d=0.0144) Done. MaxErr=8.49e-01, MedErr=-1.08e-02, NSpikes=29, Time=0.05s
# 2025-04-12 10:11:09,373 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0145): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:09,423 - src.parametric.studies - INFO - 	(fs=20000_d=0.0145) Done. MaxErr=8.16e-01, MedErr=2.72e-03, NSpikes=29, Time=0.05s
# 2025-04-12 10:11:11,050 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0146): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:11,099 - src.parametric.studies - INFO - 	(fs=20000_d=0.0146) Done. MaxErr=8.77e-01, MedErr=2.69e-02, NSpikes=29, Time=0.05s
# 2025-04-12 10:11:12,780 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0147): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:12,869 - src.parametric.studies - INFO - 	(fs=20000_d=0.0147) Done. MaxErr=1.04e+00, MedErr=2.43e-02, NSpikes=28, Time=0.08s
# 2025-04-12 10:11:15,416 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0148): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:15,503 - src.parametric.studies - INFO - 	(fs=20000_d=0.0148) Done. MaxErr=1.04e+00, MedErr=1.31e-02, NSpikes=28, Time=0.08s
# 2025-04-12 10:11:17,538 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0149): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:17,589 - src.parametric.studies - INFO - 	(fs=20000_d=0.0149) Done. MaxErr=9.57e-01, MedErr=2.96e-02, NSpikes=28, Time=0.05s
# 2025-04-12 10:11:19,392 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0150): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:19,444 - src.parametric.studies - INFO - 	(fs=20000_d=0.0150) Done. MaxErr=8.56e-01, MedErr=4.72e-03, NSpikes=28, Time=0.05s
# 2025-04-12 10:11:21,062 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0151): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:21,111 - src.parametric.studies - INFO - 	(fs=20000_d=0.0151) Done. MaxErr=8.29e-01, MedErr=8.65e-04, NSpikes=27, Time=0.05s
# 2025-04-12 10:11:22,737 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0152): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:22,789 - src.parametric.studies - INFO - 	(fs=20000_d=0.0152) Done. MaxErr=8.24e-01, MedErr=-1.08e-02, NSpikes=27, Time=0.05s
# 2025-04-12 10:11:24,396 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0153): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:24,443 - src.parametric.studies - INFO - 	(fs=20000_d=0.0153) Done. MaxErr=9.24e-01, MedErr=1.14e-02, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:26,291 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0154): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:26,341 - src.parametric.studies - INFO - 	(fs=20000_d=0.0154) Done. MaxErr=9.69e-01, MedErr=4.87e-03, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:28,759 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0155): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:28,852 - src.parametric.studies - INFO - 	(fs=20000_d=0.0155) Done. MaxErr=9.83e-01, MedErr=3.58e-03, NSpikes=26, Time=0.09s
# 2025-04-12 10:11:31,128 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0156): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:31,175 - src.parametric.studies - INFO - 	(fs=20000_d=0.0156) Done. MaxErr=1.00e+00, MedErr=2.05e-03, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:32,846 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0157): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:32,896 - src.parametric.studies - INFO - 	(fs=20000_d=0.0157) Done. MaxErr=1.01e+00, MedErr=1.18e-03, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:34,784 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0158): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:34,832 - src.parametric.studies - INFO - 	(fs=20000_d=0.0158) Done. MaxErr=1.02e+00, MedErr=-4.15e-04, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:36,445 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0159): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:36,493 - src.parametric.studies - INFO - 	(fs=20000_d=0.0159) Done. MaxErr=1.02e+00, MedErr=-6.87e-04, NSpikes=26, Time=0.04s
# 2025-04-12 10:11:38,086 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0160): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:38,134 - src.parametric.studies - INFO - 	(fs=20000_d=0.0160) Done. MaxErr=1.02e+00, MedErr=-5.74e-04, NSpikes=26, Time=0.04s
# 2025-04-12 10:11:39,725 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0161): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:39,781 - src.parametric.studies - INFO - 	(fs=20000_d=0.0161) Done. MaxErr=1.02e+00, MedErr=-2.27e-04, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:42,075 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0162): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:42,165 - src.parametric.studies - INFO - 	(fs=20000_d=0.0162) Done. MaxErr=1.01e+00, MedErr=-2.13e-04, NSpikes=26, Time=0.09s
# 2025-04-12 10:11:44,656 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0163): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:44,705 - src.parametric.studies - INFO - 	(fs=20000_d=0.0163) Done. MaxErr=1.01e+00, MedErr=-3.49e-04, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:46,326 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0164): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:46,374 - src.parametric.studies - INFO - 	(fs=20000_d=0.0164) Done. MaxErr=1.00e+00, MedErr=1.82e-05, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:47,949 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0165): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:48,000 - src.parametric.studies - INFO - 	(fs=20000_d=0.0165) Done. MaxErr=9.97e-01, MedErr=5.77e-05, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:49,642 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0166): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:49,694 - src.parametric.studies - INFO - 	(fs=20000_d=0.0166) Done. MaxErr=9.90e-01, MedErr=-1.40e-04, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:51,545 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0167): b=1.000, dte=0.0e+00...
# 2025-04-12 10:11:51,594 - src.parametric.studies - INFO - 	(fs=20000_d=0.0167) Done. MaxErr=9.82e-01, MedErr=2.56e-05, NSpikes=26, Time=0.05s
# 2025-04-12 10:11:53,234 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0168): b=1.000, dte=0.0e+00...
# ...
# 2025-04-12 10:36:56,241 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0959): b=1.000, dte=0.0e+00...
# 2025-04-12 10:36:56,290 - src.parametric.studies - INFO - 	(fs=20000_d=0.0959) Done. MaxErr=1.31e+00, MedErr=1.80e-02, NSpikes=5, Time=0.05s
# 2025-04-12 10:36:57,887 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0960): b=1.000, dte=0.0e+00...
# 2025-04-12 10:36:57,924 - src.parametric.studies - INFO - 	(fs=20000_d=0.0960) Done. MaxErr=1.32e+00, MedErr=1.80e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:36:59,747 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0961): b=1.000, dte=0.0e+00...
# 2025-04-12 10:36:59,785 - src.parametric.studies - INFO - 	(fs=20000_d=0.0961) Done. MaxErr=1.32e+00, MedErr=1.81e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:02,127 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0962): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:02,198 - src.parametric.studies - INFO - 	(fs=20000_d=0.0962) Done. MaxErr=1.33e+00, MedErr=1.83e-02, NSpikes=5, Time=0.07s
# 2025-04-12 10:37:04,422 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0963): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:04,475 - src.parametric.studies - INFO - 	(fs=20000_d=0.0963) Done. MaxErr=1.33e+00, MedErr=1.86e-02, NSpikes=5, Time=0.05s
# 2025-04-12 10:37:06,104 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0964): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:06,142 - src.parametric.studies - INFO - 	(fs=20000_d=0.0964) Done. MaxErr=1.34e+00, MedErr=1.90e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:08,012 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0965): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:08,054 - src.parametric.studies - INFO - 	(fs=20000_d=0.0965) Done. MaxErr=1.35e+00, MedErr=1.95e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:09,671 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0966): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:09,717 - src.parametric.studies - INFO - 	(fs=20000_d=0.0966) Done. MaxErr=1.35e+00, MedErr=2.05e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:11,322 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0967): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:11,367 - src.parametric.studies - INFO - 	(fs=20000_d=0.0967) Done. MaxErr=1.36e+00, MedErr=2.10e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:12,987 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0968): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:13,027 - src.parametric.studies - INFO - 	(fs=20000_d=0.0968) Done. MaxErr=1.36e+00, MedErr=2.17e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:14,985 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0969): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:15,053 - src.parametric.studies - INFO - 	(fs=20000_d=0.0969) Done. MaxErr=1.37e+00, MedErr=2.24e-02, NSpikes=5, Time=0.06s
# 2025-04-12 10:37:17,735 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0970): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:17,803 - src.parametric.studies - INFO - 	(fs=20000_d=0.0970) Done. MaxErr=1.37e+00, MedErr=2.25e-02, NSpikes=5, Time=0.06s
# 2025-04-12 10:37:19,459 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0971): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:19,498 - src.parametric.studies - INFO - 	(fs=20000_d=0.0971) Done. MaxErr=1.38e+00, MedErr=1.94e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:21,077 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0972): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:21,124 - src.parametric.studies - INFO - 	(fs=20000_d=0.0972) Done. MaxErr=1.38e+00, MedErr=1.70e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:22,714 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0973): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:22,752 - src.parametric.studies - INFO - 	(fs=20000_d=0.0973) Done. MaxErr=1.39e+00, MedErr=1.47e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:24,529 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0974): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:24,568 - src.parametric.studies - INFO - 	(fs=20000_d=0.0974) Done. MaxErr=1.39e+00, MedErr=1.22e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:26,168 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0975): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:26,206 - src.parametric.studies - INFO - 	(fs=20000_d=0.0975) Done. MaxErr=1.39e+00, MedErr=9.86e-03, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:27,811 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0976): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:27,850 - src.parametric.studies - INFO - 	(fs=20000_d=0.0976) Done. MaxErr=1.40e+00, MedErr=7.34e-03, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:30,271 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0977): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:30,343 - src.parametric.studies - INFO - 	(fs=20000_d=0.0977) Done. MaxErr=1.40e+00, MedErr=4.94e-03, NSpikes=5, Time=0.07s
# 2025-04-12 10:37:32,679 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0978): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:32,717 - src.parametric.studies - INFO - 	(fs=20000_d=0.0978) Done. MaxErr=1.41e+00, MedErr=2.23e-03, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:34,302 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0979): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:34,339 - src.parametric.studies - INFO - 	(fs=20000_d=0.0979) Done. MaxErr=1.41e+00, MedErr=3.96e-03, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:35,928 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0980): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:35,967 - src.parametric.studies - INFO - 	(fs=20000_d=0.0980) Done. MaxErr=1.41e+00, MedErr=7.40e-03, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:37,516 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0981): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:37,554 - src.parametric.studies - INFO - 	(fs=20000_d=0.0981) Done. MaxErr=1.41e+00, MedErr=8.32e-03, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:39,158 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0982): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:39,195 - src.parametric.studies - INFO - 	(fs=20000_d=0.0982) Done. MaxErr=1.41e+00, MedErr=8.75e-03, NSpikes=5, Time=0.03s
# 2025-04-12 10:37:40,977 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0983): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:41,015 - src.parametric.studies - INFO - 	(fs=20000_d=0.0983) Done. MaxErr=1.41e+00, MedErr=1.36e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:42,998 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0984): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:43,069 - src.parametric.studies - INFO - 	(fs=20000_d=0.0984) Done. MaxErr=1.41e+00, MedErr=1.57e-02, NSpikes=5, Time=0.07s
# 2025-04-12 10:37:45,497 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0985): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:45,565 - src.parametric.studies - INFO - 	(fs=20000_d=0.0985) Done. MaxErr=1.44e+00, MedErr=1.68e-02, NSpikes=5, Time=0.07s
# 2025-04-12 10:37:47,241 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0986): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:47,283 - src.parametric.studies - INFO - 	(fs=20000_d=0.0986) Done. MaxErr=1.47e+00, MedErr=1.72e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:49,069 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0987): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:49,116 - src.parametric.studies - INFO - 	(fs=20000_d=0.0987) Done. MaxErr=1.51e+00, MedErr=1.74e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:50,684 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0988): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:50,723 - src.parametric.studies - INFO - 	(fs=20000_d=0.0988) Done. MaxErr=1.54e+00, MedErr=1.71e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:52,315 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0989): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:52,354 - src.parametric.studies - INFO - 	(fs=20000_d=0.0989) Done. MaxErr=1.58e+00, MedErr=1.68e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:53,886 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0990): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:53,924 - src.parametric.studies - INFO - 	(fs=20000_d=0.0990) Done. MaxErr=1.60e+00, MedErr=1.65e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:37:55,699 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0991): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:55,737 - src.parametric.studies - INFO - 	(fs=20000_d=0.0991) Done. MaxErr=1.61e+00, MedErr=1.59e-02, NSpikes=5, Time=0.03s
# 2025-04-12 10:37:58,144 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0992): b=1.000, dte=0.0e+00...
# 2025-04-12 10:37:58,223 - src.parametric.studies - INFO - 	(fs=20000_d=0.0992) Done. MaxErr=1.62e+00, MedErr=1.52e-02, NSpikes=5, Time=0.07s
# 2025-04-12 10:38:00,340 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0993): b=1.000, dte=0.0e+00...
# 2025-04-12 10:38:00,380 - src.parametric.studies - INFO - 	(fs=20000_d=0.0993) Done. MaxErr=1.62e+00, MedErr=1.43e-02, NSpikes=5, Time=0.04s
# 2025-04-12 10:38:01,949 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0994): b=1.000, dte=0.0e+00...
# 2025-04-12 10:38:01,997 - src.parametric.studies - INFO - 	(fs=20000_d=0.0994) Done. MaxErr=1.60e+00, MedErr=1.21e-02, NSpikes=5, Time=0.05s
# 2025-04-12 10:38:03,570 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0995): b=1.000, dte=0.0e+00...
# 2025-04-12 10:38:03,607 - src.parametric.studies - INFO - 	(fs=20000_d=0.0995) Done. MaxErr=1.55e+00, MedErr=7.10e-03, NSpikes=5, Time=0.03s
# 2025-04-12 10:38:05,380 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0996): b=1.000, dte=0.0e+00...
# 2025-04-12 10:38:05,418 - src.parametric.studies - INFO - 	(fs=20000_d=0.0996) Done. MaxErr=1.44e+00, MedErr=3.45e-03, NSpikes=5, Time=0.04s
# 2025-04-12 10:38:07,030 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0997): b=1.000, dte=0.0e+00...
# 2025-04-12 10:38:07,074 - src.parametric.studies - INFO - 	(fs=20000_d=0.0997) Done. MaxErr=1.15e+00, MedErr=-5.39e-03, NSpikes=5, Time=0.04s
# 2025-04-12 10:38:08,650 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0998): b=1.000, dte=0.0e+00...
# 2025-04-12 10:38:08,688 - src.parametric.studies - INFO - 	(fs=20000_d=0.0998) Done. MaxErr=1.03e+00, MedErr=-1.77e-02, NSpikes=5, Time=0.03s
# 2025-04-12 10:38:10,565 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.0999): b=1.000, dte=0.0e+00...
# 2025-04-12 10:38:10,635 - src.parametric.studies - INFO - 	(fs=20000_d=0.0999) Done. MaxErr=1.01e+00, MedErr=-9.39e-03, NSpikes=5, Time=0.07s
# 2025-04-12 10:38:13,311 - src.parametric.studies - INFO - 	Simulating (fs=20000_d=0.1000): b=1.000, dte=0.0e+00...
# 2025-04-12 10:38:13,384 - src.parametric.studies - INFO - 	(fs=20000_d=0.1000) Done. MaxErr=1.03e+00, MedErr=-7.33e-03, NSpikes=5, Time=0.07s
# 2025-04-12 10:38:15,075 - src.parametric.studies - INFO - Parametric study on d_norm (generated_multisin) complete. 1000 points successfully processed.
# 2025-04-12 10:38:15,076 - src.controllers.parametric_handler - INFO - 	Delta study for generated_multisin completed.
# 2025-04-12 10:38:15,144 - src.utilities.plotting - WARNING - 	Non-positive values found in 'Median Error' for 'Delta Study Summary'. Plotting on linear scale.
# 2025-04-12 10:38:17,013 - src.controllers.parametric_handler - INFO - --- Saving Parametric Study Summary Results ---
# 2025-04-12 10:38:17,013 - src.controllers.parametric_handler - INFO - 	Saving summary results for signal: generated_multisin
# 2025-04-12 10:38:17,013 - src.controllers.parametric_handler - INFO - 		Saving SUMMARY 'delta' metrics to Excel: parametric_delta_summary_generated_multisin.xlsx
# 2025-04-12 10:38:17,951 - src.controllers.parametric_handler - INFO - 		Saving SUMMARY 'delta' metrics to Pickle: parametric_delta_summary_generated_multisin.pkl
# 2025-04-12 10:38:17,961 - src.controllers.parametric_handler - INFO - --- Summary Results Saving Complete ---
# 2025-04-12 10:38:17,962 - src.controllers.parametric_handler - INFO - === Parametric Handler Finished ===
#
# 2025-04-12 10:38:17,962 - __main__ - INFO - Parametric handler completed successfully.
# 2025-04-12 10:38:17,962 - __main__ - INFO -
# --- Starting Results Workflow (Results Handler) ---
# 2025-04-12 10:38:17,962 - __main__ - INFO - Results manager will use data from the current Execution workflow run.
# 2025-04-12 10:38:17,962 - src.controllers.results_handler - INFO - ====== Results Handler Manager ======
# 2025-04-12 10:38:17,962 - src.controllers.results_handler - INFO - Using live parametric summary results passed from the execution flow.
# 2025-04-12 10:38:17,962 - src.controllers.results_handler - INFO -
# >>> Processing Results for Signal: [generated_multisin] <<<
# 2025-04-12 10:38:17,962 - src.analysis.optima - INFO - --- Running Optima_generated_multisin ---
# 2025-04-12 10:38:17,962 - src.analysis.optima - INFO - --- Finding Optimal Conditions [generated_multisin] ---
# 2025-04-12 10:38:17,962 - src.analysis.optima - INFO - Attempting to find optimal conditions...
# 2025-04-12 10:38:17,962 - src.analysis.optima - INFO - 2D sweep data not available or empty. Checking 1D sweeps...
# 2025-04-12 10:38:17,962 - src.analysis.optima - INFO - Analyzing 1D Delta sweep (Priority 3)...
# 2025-04-12 10:38:17,967 - src.analysis.optima - INFO - 	Selected best candidate meeting thresholds: Sampling Frequency (Hz)=20000.0, Normalized Threshold=0.021500000000000002, Median Error=-7.734e-02, Elapsed Time (s)=0.042s
# 2025-04-12 10:38:17,967 - src.analysis.optima - INFO - Found suitable candidate from 1D Delta sweep (using Default Frequency=20000.0).
# 2025-04-12 10:38:17,967 - src.analysis.optima - INFO - Final optimal candidate selected from 'delta' results.
# 2025-04-12 10:38:17,967 - src.analysis.optima - INFO - 	Final Optimal Values: Sampling Frequency (Hz)=2e+04, Normalized Threshold=0.0215, Max Error=1.146, Median Error=-0.07734, Normalized RMSE (std)=1.233, Elapsed Time (s)=0.04158, Encoded Length=19, source_study_type=delta
# 2025-04-12 10:38:17,967 - src.analysis.optima - INFO - 	Optimal conditions found: fs=20000.0, d_norm=0.021500000000000002
# 2025-04-12 10:38:17,967 - src.analysis.optima - INFO - --- Simulating Optimal Conditions [generated_multisin] ---
# 2025-04-12 10:38:17,967 - src.analysis.optima - INFO - 	Running simulation with optimal fs=20000.0, d_norm=0.0215...
# 2025-04-12 10:38:18,011 - src.analysis.optima - INFO -   Using stable region indices [1000:19000] for metrics.
# 2025-04-12 10:38:18,014 - src.analysis.optima - INFO - 	Optimal Run Metrics (Stable Region): MedErr=-0.0773, NSpikes=19, Time=0.0439s
# 2025-04-12 10:38:18,048 - src.analysis.optima - INFO - 	Saved optimal run summary for generated_multisin.
# 2025-04-12 10:38:18,064 - src.analysis.optima - INFO - 	Saved optimal raw data pickle for generated_multisin.
# 2025-04-12 10:38:18,064 - src.analysis.optima - INFO - 	Plotting optimal results for generated_multisin...
# 2025-04-12 10:38:19,676 - src.analysis.optima - INFO - 	Optimal simulation completed successfully for generated_multisin.
# 2025-04-12 10:38:19,676 - src.analysis.optima - INFO - Optimal simulation for generated_multisin completed. N_spikes = 19
# 2025-04-12 10:38:19,676 - src.analysis.nyquist - INFO - --- Running Nyquist_generated_multisin ---
# 2025-04-12 10:38:19,676 - src.analysis.nyquist - INFO - 	Testing N from 40 to 19 (0 values).
# 2025-04-12 10:38:19,676 - src.analysis.nyquist - WARNING - Nyquist_generated_multisin: Analysis completed, but no results generated.
# 2025-04-12 10:38:19,676 - src.controllers.results_handler - WARNING - Skipping Fourier analysis for generated_multisin: Required optimal simulation results not available (simulation likely failed or was skipped).
# 2025-04-12 10:38:19,676 - src.controllers.results_handler - INFO - Completed processing all signals.
# 2025-04-12 10:38:19,676 - src.controllers.results_handler - INFO - ====== Results Handler Finished ======
# 2025-04-12 10:38:19,676 - __main__ - INFO - Results handler completed.
# 2025-04-12 10:38:19,676 - __main__ - INFO -
# --- Plant Operations Complete ---
